# %%
from email.mime import image
import os
# D:\Projects\Predictive_Analytics\Data_sets
os.chdir("D:\Project\Predictive_Analytics\Data_sets")

import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt



matplotlib.style.use('ggplot')
# %matplotlib inline

# %%
df = pd.read_csv("GroupedMatchInfo29.09.2022.csv", sep=',', header=0    , index_col=False)

df = df.drop(columns=['MatchId'])

# %%
df.head()
# Out:
#    RadiantWin  RadiantHeroIdPick1  RadiantHeroIdPick2  RadiantHeroIdPick3  \
# 0        True               False               False               False
# 1        True               False               False               False
# 2       False               False                True               False
# 3        True               False               False                True
# 4       False               False               False               False
#
#    RadiantHeroIdPick4  RadiantHeroIdPick5  RadiantHeroIdPick6  \
# 0               False                True               False
# 1               False               False               False
# 2               False               False               False
# 3               False               False               False
# 4               False               False               False
#
#    RadiantHeroIdPick7  RadiantHeroIdPick8  RadiantHeroIdPick9  ...  \
# 0               False                True               False  ...
# 1               False               False               False  ...
# 2               False                True               False  ...
# 3               False                True               False  ...
# 4               False               False               False  ...
#
#    RadiantHero4PercentageDireHero1  RadiantHero4PercentageDireHero2  \
# 0                           0.5394                           0.5345
# 1                           0.5180                           0.5453
# 2                           0.5002                           0.5375
# 3                           0.5021                           0.4570
# 4                           0.4865                           0.5032
#
#    RadiantHero4PercentageDireHero3  RadiantHero4PercentageDireHero4  \
# 0                           0.4930                           0.5680
# 1                           0.5556                           0.5591
# 2                           0.5713                           0.5417
# 3                           0.4880                           0.4193
# 4                           0.5270                           0.5272
#
#    RadiantHero4PercentageDireHero5  RadiantHero5PercentageDireHero1  \
# 0                           0.4953                           0.5163
# 1                           0.5330                           0.5100
# 2                           0.5316                           0.4874
# 3                           0.4607                           0.5394
# 4                           0.4598                           0.4756
#
#    RadiantHero5PercentageDireHero2  RadiantHero5PercentageDireHero3  \
# 0                           0.5173                           0.4782
# 1                           0.5315                           0.5422
# 2                           0.5382                           0.5434
# 3                           0.4882                           0.5141
# 4                           0.4947                           0.5467
#
#    RadiantHero5PercentageDireHero4  RadiantHero5PercentageDireHero5
# 0                           0.5561                           0.4902
# 1                           0.5726                           0.5555
# 2                           0.5390                           0.5715
# 3                           0.4584                           0.4648
# 4                           0.5150                           0.4853
#
# [5 rows x 560 columns]

# %%
list = []
for i in range(1,11):
    list.append('STR' + str(i))
    list.append('STRPerLevel' + str(i))
    list.append('STR30' + str(i))
    list.append('AGI' + str(i))
    list.append('AGIPerLevel' + str(i))
    list.append('AGI30' + str(i))
    list.append('INT' + str(i))
    list.append('INTPerLevel' + str(i))
    list.append('INT30' + str(i))
    list.append('T' + str(i))
    list.append('TPerLevel' + str(i))
    list.append('T30' + str(i))
    list.append('MS' + str(i))
    list.append('AR' + str(i))
    list.append('DMGMAX' + str(i))
    list.append('RG' + str(i))
    list.append('AS' + str(i))
    list.append('BAT' + str(i))
    list.append('ATKPT' + str(i))
    list.append('VSD' + str(i))
    list.append('VSN' + str(i))
    list.append('TR' + str(i))
    list.append('COL' + str(i))
    list.append('HPS' + str(i))
    list.append('Legs' + str(i))

dfDroped = df.drop(columns=list)

# %%
dfDroped.head()
# Out:
#    RadiantWin  RadiantHeroIdPick1  RadiantHeroIdPick2  RadiantHeroIdPick3  \
# 0        True               False               False               False
# 1        True               False               False               False
# 2       False               False                True               False
# 3        True               False               False                True
# 4       False               False               False               False
#
#    RadiantHeroIdPick4  RadiantHeroIdPick5  RadiantHeroIdPick6  \
# 0               False                True               False
# 1               False               False               False
# 2               False               False               False
# 3               False               False               False
# 4               False               False               False
#
#    RadiantHeroIdPick7  RadiantHeroIdPick8  RadiantHeroIdPick9  ...  \
# 0               False                True               False  ...
# 1               False               False               False  ...
# 2               False                True               False  ...
# 3               False                True               False  ...
# 4               False               False               False  ...
#
#    RadiantHero4PercentageDireHero1  RadiantHero4PercentageDireHero2  \
# 0                           0.5394                           0.5345
# 1                           0.5180                           0.5453
# 2                           0.5002                           0.5375
# 3                           0.5021                           0.4570
# 4                           0.4865                           0.5032
#
#    RadiantHero4PercentageDireHero3  RadiantHero4PercentageDireHero4  \
# 0                           0.4930                           0.5680
# 1                           0.5556                           0.5591
# 2                           0.5713                           0.5417
# 3                           0.4880                           0.4193
# 4                           0.5270                           0.5272
#
#    RadiantHero4PercentageDireHero5  RadiantHero5PercentageDireHero1  \
# 0                           0.4953                           0.5163
# 1                           0.5330                           0.5100
# 2                           0.5316                           0.4874
# 3                           0.4607                           0.5394
# 4                           0.4598                           0.4756
#
#    RadiantHero5PercentageDireHero2  RadiantHero5PercentageDireHero3  \
# 0                           0.5173                           0.4782
# 1                           0.5315                           0.5422
# 2                           0.5382                           0.5434
# 3                           0.4882                           0.5141
# 4                           0.4947                           0.5467
#
#    RadiantHero5PercentageDireHero4  RadiantHero5PercentageDireHero5
# 0                           0.5561                           0.4902
# 1                           0.5726                           0.5555
# 2                           0.5390                           0.5715
# 3                           0.4584                           0.4648
# 4                           0.5150                           0.4853
#
# [5 rows x 310 columns]

# %% [markdown]
# # Logistic Regression

# %%
dfResults =  pd.DataFrame()

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression


features = dfDroped.drop(columns=['RadiantWin'])
labels = df['RadiantWin']
test_size = 0.4
X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size = test_size)


model = LogisticRegression(solver='lbfgs', max_iter=100000)
model.fit(X_train, y_train)


# predict probabilities
pred_prob = model.predict_proba(X_train)


dfResults.loc[0,'Test_accuracy'] = model.score(X_test, y_test)
dfResults.loc[0,'Training_accuracy'] = model.score(X_train, y_train)
dfResults.loc[0,'test_size'] = test_size
dfResults
# Out:
#    Test_accuracy  Training_accuracy  test_size
# 0       0.573127           0.586895        0.4

# %%
for i in range(9):
    test_size = (i+1)/10   
    X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size = test_size)
    model = LogisticRegression()
    model.fit(X_train, y_train)

    dfResults.loc[i,'Test_accuracy'] = model.score(X_test, y_test)
    dfResults.loc[i,'Training_accuracy'] = model.score(X_train, y_train)
    dfResults.loc[i,'test_size'] = test_size
dfResults
# Out:
#    Test_accuracy  Training_accuracy  test_size
# 0       0.510750           0.515193        0.1
# 1       0.506465           0.513586        0.2
# 2       0.514142           0.510940        0.3
# 3       0.514493           0.516468        0.4
# 4       0.513019           0.515373        0.5
# 5       0.507095           0.517001        0.6
# 6       0.498505           0.513417        0.7
# 7       0.509354           0.510317        0.8
# 8       0.505069           0.520488        0.9

# %% [markdown]
# # Random forest

# %%
from sklearn.ensemble import RandomForestClassifier
dfResults =  pd.DataFrame()
for i in range(10):
    
    model = RandomForestClassifier(max_depth = 9, n_estimators=300)
    model.fit(X_train, y_train)

    # predict probabilities
    pred_prob = model.predict_proba(X_test)

    print('Test accuracy: ', model.score(X_test, y_test))
    print('Training accuracy: ', model.score(X_train, y_train))

    from sklearn.metrics import roc_curve
    from sklearn.metrics import roc_auc_score
    auc_score = roc_auc_score(y_test, pred_prob[:,1])
    print(auc_score)
# Out:
# Test accuracy:  0.5628841253185429
# Training accuracy:  0.6827009560611612
# 0.5908316715745427
# Test accuracy:  0.5649327936841053
# Training accuracy:  0.6840001332489424
# 0.5900380341921827
# Test accuracy:  0.563083995402988
# Training accuracy:  0.6842333188980313
# 0.5895804837550719
# Test accuracy:  0.5644830859941038
# Training accuracy:  0.6847996269029615
# 0.591090707801184
# Test accuracy:  0.5613351321640934
# Training accuracy:  0.6843332556047836
# 0.5892847647948665
# Test accuracy:  0.5645330535152151
# Training accuracy:  0.683667010893101
# 0.5915201644377187
# Test accuracy:  0.5638834757407685
# Training accuracy:  0.6858656184416536
# 0.5905112045027741
# Test accuracy:  0.5643831509518813
# Training accuracy:  0.6840001332489424
# 0.5913061002636882
# Test accuracy:  0.5640333783041024
# Training accuracy:  0.685199373729971
# 0.5900092213181471
# Test accuracy:  0.5632338979663218
# Training accuracy:  0.6853992471434758
# 0.5900321018361421
